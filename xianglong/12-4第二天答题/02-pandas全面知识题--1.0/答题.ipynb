# %%
import pandas as pd
from pandas import DataFrame, Series
import numpy as np
import matplotlib as plopt
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('data.csv', header=0, encoding='gbk')
df
# Out:
#           订单号  订单行        销售时间        交货时间 货品交货状况   货品 货品用户反馈  销售区域    数量  \
# 0     P096311   10   2016/7/30   2016/9/30    晚交货  货品3   质量合格    华北   2.0
# 1     P096826   10   2016/8/30  2016/10/30   按时交货  货品3   质量合格    华北  10.0
# 2         NaN   20   2016/8/30  2016/10/30   按时交货  货品3   质量合格    华北  10.0
# 3     P097435   10   2016/7/30   2016/9/30   按时交货  货品1     返修    华南   2.0
# 4     P097446   60  2016/11/26   2017/1/26    晚交货  货品3   质量合格    华北  15.0
# ...       ...  ...         ...         ...    ...  ...    ...   ...   ...
# 1156  P299901   10  2016/12/15   2017/3/15   按时交货  货品6   质量合格  马来西亚   2.0
# 1157  P302956   10  2016/12/22   2017/3/22   按时交货  货品2     拒货    华东  20.0
# 1158  P303801   10  2016/12/15   2017/3/15   按时交货  货品2   质量合格    华东   1.0
# 1159  P307276   10  2016/12/22   2017/3/22   按时交货  货品6   质量合格  马来西亚   1.0
# 1160  P314165   10  2016/12/20   2017/3/20   按时交货  货品2   质量合格    华东   1.0
#
#           销售金额
# 0     1052,75元
# 1      11,50万元
# 2      11,50万元
# ...

# %%
pd.read_csv('data.csv', header=None)
# Out:
#             0       1           2           3           4     5           6  \
# 0      ������  ������     ����ʱ��     ����ʱ��  ��Ʒ����״��   ��Ʒ  ��Ʒ�û�����
# 1     P096311      10   2016/7/30   2016/9/30      ������  ��Ʒ3     �����ϸ�
# 2     P096826      10   2016/8/30  2016/10/30     ��ʱ����  ��Ʒ3     �����ϸ�
# 3         NaN      20   2016/8/30  2016/10/30     ��ʱ����  ��Ʒ3     �����ϸ�
# 4     P097435      10   2016/7/30   2016/9/30     ��ʱ����  ��Ʒ1        ����
# ...       ...     ...         ...         ...         ...   ...         ...
# 1157  P299901      10  2016/12/15   2017/3/15     ��ʱ����  ��Ʒ6     �����ϸ�
# 1158  P302956      10  2016/12/22   2017/3/22     ��ʱ����  ��Ʒ2         �ܻ�
# 1159  P303801      10  2016/12/15   2017/3/15     ��ʱ����  ��Ʒ2     �����ϸ�
# 1160  P307276      10  2016/12/22   2017/3/22     ��ʱ����  ��Ʒ6     �����ϸ�
# 1161  P314165      10  2016/12/20   2017/3/20     ��ʱ����  ��Ʒ2     �����ϸ�
#
#              7     8         9
# ...

# %%
pd.read_csv('data.csv', names=['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i'], header=1)
# Out:
#           a           b           c         d     e        f         g     h  \
# P096826  10   2016/8/30  2016/10/30   ��ʱ����  ��Ʒ3  �����ϸ�      ����  10.0
# NaN      20   2016/8/30  2016/10/30   ��ʱ����  ��Ʒ3  �����ϸ�      ����  10.0
# P097435  10   2016/7/30   2016/9/30   ��ʱ����  ��Ʒ1     ����      ����   2.0
# P097446  60  2016/11/26   2017/1/26    ������  ��Ʒ3  �����ϸ�      ����  15.0
# P097446  80  2016/11/26   2017/1/26    ������  ��Ʒ3      �ܻ�      ����  15.0
# ...      ..         ...         ...       ...   ...      ...       ...   ...
# P299901  10  2016/12/15   2017/3/15   ��ʱ����  ��Ʒ6  �����ϸ�  ��������   2.0
# P302956  10  2016/12/22   2017/3/22   ��ʱ����  ��Ʒ2      �ܻ�      ����  20.0
# P303801  10  2016/12/15   2017/3/15   ��ʱ����  ��Ʒ2  �����ϸ�      ����   1.0
# P307276  10  2016/12/22   2017/3/22   ��ʱ����  ��Ʒ6  �����ϸ�  ��������   1.0
# P314165  10  2016/12/20   2017/3/20   ��ʱ����  ��Ʒ2  �����ϸ�      ����   1.0
#
#                 i
# P096826  11,50��Ԫ
# ...

# %%
pd.read_csv('data.csv', names=['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i'], encoding='gbk')
# Out:
#            a           b           c       d    e       f     g   h         i
# 订单号      订单行        销售时间        交货时间  货品交货状况   货品  货品用户反馈  销售区域  数量      销售金额
# P096311   10   2016/7/30   2016/9/30     晚交货  货品3    质量合格    华北   2  1052,75元
# P096826   10   2016/8/30  2016/10/30    按时交货  货品3    质量合格    华北  10   11,50万元
# NaN       20   2016/8/30  2016/10/30    按时交货  货品3    质量合格    华北  10   11,50万元
# P097435   10   2016/7/30   2016/9/30    按时交货  货品1      返修    华南   2  6858,77元
# ...      ...         ...         ...     ...  ...     ...   ...  ..       ...
# P299901   10  2016/12/15   2017/3/15    按时交货  货品6    质量合格  马来西亚   2   200,41元
# P302956   10  2016/12/22   2017/3/22    按时交货  货品2      拒货    华东  20    79,44元
# P303801   10  2016/12/15   2017/3/15    按时交货  货品2    质量合格    华东   1   194,08元
# P307276   10  2016/12/22   2017/3/22    按时交货  货品6    质量合格  马来西亚   1    32,18元
# P314165   10  2016/12/20   2017/3/20    按时交货  货品2    质量合格    华东   1  1720,92元
#
# [1162 rows x 9 columns]

# %%
pd.read_csv('data.csv', index_col=['订单号', '订单行'], encoding='gbk')
# Out:
#                    销售时间        交货时间 货品交货状况   货品 货品用户反馈  销售区域    数量      销售金额
# 订单号     订单行
# P096311 10    2016/7/30   2016/9/30    晚交货  货品3   质量合格    华北   2.0  1052,75元
# P096826 10    2016/8/30  2016/10/30   按时交货  货品3   质量合格    华北  10.0   11,50万元
# NaN     20    2016/8/30  2016/10/30   按时交货  货品3   质量合格    华北  10.0   11,50万元
# P097435 10    2016/7/30   2016/9/30   按时交货  货品1     返修    华南   2.0  6858,77元
# P097446 60   2016/11/26   2017/1/26    晚交货  货品3   质量合格    华北  15.0   129,58元
# ...                 ...         ...    ...  ...    ...   ...   ...       ...
# P299901 10   2016/12/15   2017/3/15   按时交货  货品6   质量合格  马来西亚   2.0   200,41元
# P302956 10   2016/12/22   2017/3/22   按时交货  货品2     拒货    华东  20.0    79,44元
# P303801 10   2016/12/15   2017/3/15   按时交货  货品2   质量合格    华东   1.0   194,08元
# P307276 10   2016/12/22   2017/3/22   按时交货  货品6   质量合格  马来西亚   1.0    32,18元
# P314165 10   2016/12/20   2017/3/20   按时交货  货品2   质量合格    华东   1.0  1720,92元
#
# [1161 rows x 8 columns]

# %%
pd.read_csv('data.csv', encoding='gbk', usecols=['订单号', '订单行'])
# Out:
#           订单号  订单行
# 0     P096311   10
# 1     P096826   10
# 2         NaN   20
# 3     P097435   10
# 4     P097446   60
# ...       ...  ...
# 1156  P299901   10
# 1157  P302956   10
# 1158  P303801   10
# 1159  P307276   10
# 1160  P314165   10
#
# [1161 rows x 2 columns]

# %%
df = pd.read_csv('data.csv', encoding='gbk', nrows=100)
df
# Out:
#         订单号  订单行        销售时间        交货时间 货品交货状况   货品 货品用户反馈 销售区域    数量  \
# 0   P096311   10   2016/7/30   2016/9/30    晚交货  货品3   质量合格   华北   2.0
# 1   P096826   10   2016/8/30  2016/10/30   按时交货  货品3   质量合格   华北  10.0
# 2       NaN   20   2016/8/30  2016/10/30   按时交货  货品3   质量合格   华北  10.0
# 3   P097435   10   2016/7/30   2016/9/30   按时交货  货品1     返修   华南   2.0
# 4   P097446   60  2016/11/26   2017/1/26    晚交货  货品3   质量合格   华北  15.0
# ..      ...  ...         ...         ...    ...  ...    ...  ...   ...
# 95  P137613   10   2016/8/31  2016/10/31   按时交货  货品3   质量合格   华北   1.0
# 96  P137613   20   2016/8/31  2016/10/31   按时交货  货品3   质量合格   华北   1.0
# 97  P138559   10   2016/8/30  2016/10/30   按时交货  货品1   质量合格   华北   1.0
# 98  P144800   10   2016/8/16  2016/11/16    晚交货  货品3     拒货   华北   1.0
# 99  P144841   10   2016/8/24  2016/11/24   按时交货  货品5   质量合格   泰国   1.0
#
#          销售金额
# 0    1052,75元
# 1     11,50万元
# 2     11,50万元
# 3    6858,77元
# 4     129,58元
# ..        ...
# ...

# %%
pd.read_csv('data.csv', encoding='gbk', header=100, names=['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i','j'])
# Out:
#             a   b           c          d      e    f     g     h     i  \
# 0     P146012  10  2016/10/17  2017/1/17    晚交货  货品2    拒货    华东   1.0
# 1     P146166  10   2016/7/30  2016/9/30    晚交货  货品2    拒货    华东   1.0
# 2     P150740  10   2016/7/30  2016/9/30   按时交货  货品4  质量合格    西北   2.0
# 3     P150740  20   2016/7/30  2016/9/30    晚交货  货品4  质量合格    西北   2.0
# 4     P152820  10   2016/7/30  2016/9/30   按时交货  货品3  质量合格    华北  40.0
# ...       ...  ..         ...        ...    ...  ...   ...   ...   ...
# 1056  P299901  10  2016/12/15  2017/3/15   按时交货  货品6  质量合格  马来西亚   2.0
# 1057  P302956  10  2016/12/22  2017/3/22   按时交货  货品2    拒货    华东  20.0
# 1058  P303801  10  2016/12/15  2017/3/15   按时交货  货品2  质量合格    华东   1.0
# 1059  P307276  10  2016/12/22  2017/3/22   按时交货  货品6  质量合格  马来西亚   1.0
# 1060  P314165  10  2016/12/20  2017/3/20   按时交货  货品2  质量合格    华东   1.0
#
#               j
# 0     19283,90元
# 1       557,17元
# 2       351,52元
# 3       371,15元
# 4        34,07元
# ...

# %%
df.to_csv('./第一题.csv', encoding='utf-8')

# %%
df = pd.read_csv('data.csv', encoding='gbk')
df
# Out:
#           订单号  订单行        销售时间        交货时间 货品交货状况   货品 货品用户反馈  销售区域    数量  \
# 0     P096311   10   2016/7/30   2016/9/30    晚交货  货品3   质量合格    华北   2.0
# 1     P096826   10   2016/8/30  2016/10/30   按时交货  货品3   质量合格    华北  10.0
# 2         NaN   20   2016/8/30  2016/10/30   按时交货  货品3   质量合格    华北  10.0
# 3     P097435   10   2016/7/30   2016/9/30   按时交货  货品1     返修    华南   2.0
# 4     P097446   60  2016/11/26   2017/1/26    晚交货  货品3   质量合格    华北  15.0
# ...       ...  ...         ...         ...    ...  ...    ...   ...   ...
# 1156  P299901   10  2016/12/15   2017/3/15   按时交货  货品6   质量合格  马来西亚   2.0
# 1157  P302956   10  2016/12/22   2017/3/22   按时交货  货品2     拒货    华东  20.0
# 1158  P303801   10  2016/12/15   2017/3/15   按时交货  货品2   质量合格    华东   1.0
# 1159  P307276   10  2016/12/22   2017/3/22   按时交货  货品6   质量合格  马来西亚   1.0
# 1160  P314165   10  2016/12/20   2017/3/20   按时交货  货品2   质量合格    华东   1.0
#
#           销售金额
# 0     1052,75元
# 1      11,50万元
# 2      11,50万元
# ...

# %%
df.duplicated().value_counts()
# Out:
# False    1152
# True        9
# dtype: int64

# %%
df[df.duplicated()].head()
# Out:
#         订单号  订单行       销售时间        交货时间 货品交货状况   货品 货品用户反馈 销售区域   数量  \
# 12  P098065   10  2016/7/15  2016/10/15   按时交货  货品2     返修   华东  1.0
# 13  P098065   20  2016/8/10  2016/11/10   按时交货  货品1   质量合格   华南  1.0
# 14  P098823   10  2016/9/30  2016/11/30   按时交货  货品1     拒货   华南  2.0
# 15  P099725   10   2016/8/3   2016/11/3    晚交货  货品3   质量合格   华北  1.0
# 16  P101535   10  2016/7/15  2016/10/15   按时交货  货品3     返修   华北  NaN
#
#          销售金额
# 12  22192,97元
# 13  25723,04元
# 14   6934,75元
# 15   1319,63元
# 16    700,53元

# %%
df.drop_duplicates(subset=['订单号', '订单行'], keep='first', inplace=True)

# %%
df
# Out:
#           订单号  订单行        销售时间        交货时间 货品交货状况   货品 货品用户反馈  销售区域    数量  \
# 0     P096311   10   2016/7/30   2016/9/30    晚交货  货品3   质量合格    华北   2.0
# 1     P096826   10   2016/8/30  2016/10/30   按时交货  货品3   质量合格    华北  10.0
# 2         NaN   20   2016/8/30  2016/10/30   按时交货  货品3   质量合格    华北  10.0
# 3     P097435   10   2016/7/30   2016/9/30   按时交货  货品1     返修    华南   2.0
# 4     P097446   60  2016/11/26   2017/1/26    晚交货  货品3   质量合格    华北  15.0
# ...       ...  ...         ...         ...    ...  ...    ...   ...   ...
# 1156  P299901   10  2016/12/15   2017/3/15   按时交货  货品6   质量合格  马来西亚   2.0
# 1157  P302956   10  2016/12/22   2017/3/22   按时交货  货品2     拒货    华东  20.0
# 1158  P303801   10  2016/12/15   2017/3/15   按时交货  货品2   质量合格    华东   1.0
# 1159  P307276   10  2016/12/22   2017/3/22   按时交货  货品6   质量合格  马来西亚   1.0
# 1160  P314165   10  2016/12/20   2017/3/20   按时交货  货品2   质量合格    华东   1.0
#
#           销售金额
# 0     1052,75元
# 1      11,50万元
# 2      11,50万元
# ...

# %%
df[df.isnull().values]
# Out:
#         订单号  订单行       销售时间        交货时间 货品交货状况   货品 货品用户反馈  销售区域    数量  \
# 2       NaN   20  2016/8/30  2016/10/30   按时交货  货品3   质量合格    华北  10.0
# 10  P101535   10  2016/7/15  2016/10/15   按时交货  货品3     返修    华北   NaN
# 32  P122051   10  2016/7/15  2016/10/15   按时交货  货品6   质量合格  马来西亚   NaN
# 59  P123639   10  2016/8/15  2016/11/15    NaN  货品6   质量合格  马来西亚   2.0
#
#        销售金额
# 2   11,50万元
# 10  700,53元
# 32   42,76元
# 59   15,51元

# %%
for i in df[df.isnull().values].columns:
    print(i, True in df[df.isnull().values][i].isnull().value_counts())
# Out:
# 订单号 True
# 订单行 False
# 销售时间 False
# 交货时间 False
# 货品交货状况 True
# 货品 False
# 货品用户反馈 False
# 销售区域 False
# 数量 True
# 销售金额 False

# %%
for i in df[df.isnull().values].columns:
    print(i,4-df[df.isnull().values][i].isnull().value_counts()[0])
# Out:
# 订单号 1
# 订单行 0
# 销售时间 0
# 交货时间 0
# 货品交货状况 1
# 货品 0
# 货品用户反馈 0
# 销售区域 0
# 数量 2
# 销售金额 0

# %%
df[df.isnull().values]
# Out:
#         订单号  订单行       销售时间        交货时间 货品交货状况   货品 货品用户反馈  销售区域    数量  \
# 2       NaN   20  2016/8/30  2016/10/30   按时交货  货品3   质量合格    华北  10.0
# 10  P101535   10  2016/7/15  2016/10/15   按时交货  货品3     返修    华北   NaN
# 32  P122051   10  2016/7/15  2016/10/15   按时交货  货品6   质量合格  马来西亚   NaN
# 59  P123639   10  2016/8/15  2016/11/15    NaN  货品6   质量合格  马来西亚   2.0
#
#        销售金额
# 2   11,50万元
# 10  700,53元
# 32   42,76元
# 59   15,51元

# %%
df.dropna(how='any', axis=0, inplace=True)
df
# Out:
#           订单号  订单行        销售时间        交货时间 货品交货状况   货品 货品用户反馈  销售区域    数量  \
# 0     P096311   10   2016/7/30   2016/9/30    晚交货  货品3   质量合格    华北   2.0
# 1     P096826   10   2016/8/30  2016/10/30   按时交货  货品3   质量合格    华北  10.0
# 3     P097435   10   2016/7/30   2016/9/30   按时交货  货品1     返修    华南   2.0
# 4     P097446   60  2016/11/26   2017/1/26    晚交货  货品3   质量合格    华北  15.0
# 5     P097446   80  2016/11/26   2017/1/26    晚交货  货品3     拒货    华北  15.0
# ...       ...  ...         ...         ...    ...  ...    ...   ...   ...
# 1156  P299901   10  2016/12/15   2017/3/15   按时交货  货品6   质量合格  马来西亚   2.0
# 1157  P302956   10  2016/12/22   2017/3/22   按时交货  货品2     拒货    华东  20.0
# 1158  P303801   10  2016/12/15   2017/3/15   按时交货  货品2   质量合格    华东   1.0
# 1159  P307276   10  2016/12/22   2017/3/22   按时交货  货品6   质量合格  马来西亚   1.0
# 1160  P314165   10  2016/12/20   2017/3/20   按时交货  货品2   质量合格    华东   1.0
#
#           销售金额
# 0     1052,75元
# 1      11,50万元
# 3     6858,77元
# ...

# %%
df.fillna(0)[df.isnull().values]
# Out:
#         订单号  订单行       销售时间        交货时间 货品交货状况   货品 货品用户反馈  销售区域    数量  \
# 2         0   20  2016/8/30  2016/10/30   按时交货  货品3   质量合格    华北  10.0
# 10  P101535   10  2016/7/15  2016/10/15   按时交货  货品3     返修    华北   0.0
# 11        0   20  2016/8/22  2016/11/22   按时交货  货品3     返修    华北   4.0
# 16  P101535   10  2016/7/15  2016/10/15   按时交货  货品3     返修    华北   0.0
# 32  P122051   10  2016/7/15  2016/10/15   按时交货  货品6   质量合格  马来西亚   0.0
# 47  P122051   10  2016/7/15  2016/10/15   按时交货  货品6   质量合格  马来西亚   0.0
# 48  P122441   10  2016/8/31  2016/10/31      0  货品5     拒货    泰国   1.0
# 59  P123639   10  2016/8/15  2016/11/15      0  货品6   质量合格  马来西亚   2.0
#
#        销售金额
# 2   11,50万元
# 10  700,53元
# 11  700,53元
# 16  700,53元
# 32   42,76元
# 47   42,76元
# 48  348,74元
# 59   15,51元

# %%
df.fillna({'订单号': '无订单号', '货品交货状况': '按时交货', '数量': df[df.isnull().values]['数量'].mean()})[df.isnull().values]
# Out:
#         订单号  订单行       销售时间        交货时间 货品交货状况   货品 货品用户反馈  销售区域     数量  \
# 2      无订单号   20  2016/8/30  2016/10/30   按时交货  货品3   质量合格    华北  10.00
# 10  P101535   10  2016/7/15  2016/10/15   按时交货  货品3     返修    华北   4.25
# 11     无订单号   20  2016/8/22  2016/11/22   按时交货  货品3     返修    华北   4.00
# 16  P101535   10  2016/7/15  2016/10/15   按时交货  货品3     返修    华北   4.25
# 32  P122051   10  2016/7/15  2016/10/15   按时交货  货品6   质量合格  马来西亚   4.25
# 47  P122051   10  2016/7/15  2016/10/15   按时交货  货品6   质量合格  马来西亚   4.25
# 48  P122441   10  2016/8/31  2016/10/31   按时交货  货品5     拒货    泰国   1.00
# 59  P123639   10  2016/8/15  2016/11/15   按时交货  货品6   质量合格  马来西亚   2.00
#
#        销售金额
# 2   11,50万元
# 10  700,53元
# 11  700,53元
# 16  700,53元
# 32   42,76元
# 47   42,76元
# 48  348,74元
# 59   15,51元

# %%
df.fillna(method='ffill')[df.isnull().values]
# Out:
#         订单号  订单行       销售时间        交货时间 货品交货状况   货品 货品用户反馈  销售区域    数量  \
# 2   P096826   20  2016/8/30  2016/10/30   按时交货  货品3   质量合格    华北  10.0
# 10  P101535   10  2016/7/15  2016/10/15   按时交货  货品3     返修    华北   1.0
# 11  P101535   20  2016/8/22  2016/11/22   按时交货  货品3     返修    华北   4.0
# 16  P101535   10  2016/7/15  2016/10/15   按时交货  货品3     返修    华北   1.0
# 32  P122051   10  2016/7/15  2016/10/15   按时交货  货品6   质量合格  马来西亚   1.0
# 47  P122051   10  2016/7/15  2016/10/15   按时交货  货品6   质量合格  马来西亚   1.0
# 48  P122441   10  2016/8/31  2016/10/31   按时交货  货品5     拒货    泰国   1.0
# 59  P123639   10  2016/8/15  2016/11/15    晚交货  货品6   质量合格  马来西亚   2.0
#
#        销售金额
# 2   11,50万元
# 10  700,53元
# 11  700,53元
# 16  700,53元
# 32   42,76元
# 47   42,76元
# 48  348,74元
# 59   15,51元

# %%
df['销售金额'].apply(
    lambda x: 
    '万元' in x and float(x.replace('万元', '').replace(',', '.'))*10000 or
    '元' in x and float(x.replace('元', '').replace(',', '.')))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-99-738a13538eed> in <module>
# ----> 1 df['销售金额2'] = df['销售金额'].apply(
#       2     lambda x:
#       3     '万元' in x and float(x.replace('万元', '').replace(',', '.'))*10000 or
#       4     '元' in x and float(x.replace('元', '').replace(',', '.')))
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-99-738a13538eed> in <lambda>(x)
#       1 df['销售金额2'] = df['销售金额'].apply(
#       2     lambda x:
# ...

# %%
df.describe()
# Out:
#                订单行            数量
# count  1161.000000   1157.000000
# mean     13.178295     76.663354
# std       7.093713    588.138241
# min      10.000000      1.000000
# 25%      10.000000      1.000000
# 50%      10.000000      1.000000
# 75%      20.000000      4.000000
# max     100.000000  11500.000000

# %%
df = df.dropna()
x = [int(i) for i in df['数量'].values]
y = [int(i) for i in df['销售金额'].values]

# %%
# %matplotlib inline

# %%
plt.scatter(x, y)
plt.show()

# %%
df = df.drop(df[df['销售金额'] > 50000].index)
df
# Out:
#           订单号  订单行        销售时间        交货时间 货品交货状况   货品 货品用户反馈  销售区域    数量  \
# 0     P096311   10   2016/7/30   2016/9/30    晚交货  货品3   质量合格    华北   2.0
# 3     P097435   10   2016/7/30   2016/9/30   按时交货  货品1     返修    华南   2.0
# 4     P097446   60  2016/11/26   2017/1/26    晚交货  货品3   质量合格    华北  15.0
# 5     P097446   80  2016/11/26   2017/1/26    晚交货  货品3     拒货    华北  15.0
# 6     P098065   10   2016/7/15  2016/10/15   按时交货  货品2     返修    华东   1.0
# ...       ...  ...         ...         ...    ...  ...    ...   ...   ...
# 1156  P299901   10  2016/12/15   2017/3/15   按时交货  货品6   质量合格  马来西亚   2.0
# 1157  P302956   10  2016/12/22   2017/3/22   按时交货  货品2     拒货    华东  20.0
# 1158  P303801   10  2016/12/15   2017/3/15   按时交货  货品2   质量合格    华东   1.0
# 1159  P307276   10  2016/12/22   2017/3/22   按时交货  货品6   质量合格  马来西亚   1.0
# 1160  P314165   10  2016/12/20   2017/3/20   按时交货  货品2   质量合格    华东   1.0
#
#           销售金额
# 0      1052.75
# 3      6858.77
# 4       129.58
# ...

# %%
df = df.drop(df[df['数量'] > 4000].index)
df
# Out:
#           订单号  订单行        销售时间        交货时间 货品交货状况   货品 货品用户反馈  销售区域    数量  \
# 0     P096311   10   2016/7/30   2016/9/30    晚交货  货品3   质量合格    华北   2.0
# 3     P097435   10   2016/7/30   2016/9/30   按时交货  货品1     返修    华南   2.0
# 4     P097446   60  2016/11/26   2017/1/26    晚交货  货品3   质量合格    华北  15.0
# 5     P097446   80  2016/11/26   2017/1/26    晚交货  货品3     拒货    华北  15.0
# 6     P098065   10   2016/7/15  2016/10/15   按时交货  货品2     返修    华东   1.0
# ...       ...  ...         ...         ...    ...  ...    ...   ...   ...
# 1156  P299901   10  2016/12/15   2017/3/15   按时交货  货品6   质量合格  马来西亚   2.0
# 1157  P302956   10  2016/12/22   2017/3/22   按时交货  货品2     拒货    华东  20.0
# 1158  P303801   10  2016/12/15   2017/3/15   按时交货  货品2   质量合格    华东   1.0
# 1159  P307276   10  2016/12/22   2017/3/22   按时交货  货品6   质量合格  马来西亚   1.0
# 1160  P314165   10  2016/12/20   2017/3/20   按时交货  货品2   质量合格    华东   1.0
#
#           销售金额
# 0      1052.75
# 3      6858.77
# 4       129.58
# ...

# %%
# Out:
# 1.0
